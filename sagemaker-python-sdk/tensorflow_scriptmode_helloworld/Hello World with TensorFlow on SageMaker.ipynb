# %% [markdown]
# This notebook introduces development using TensorFlow on SageMaker. It starts with some "hello world"-style code examples running in local mode, and progresses to a full TensorFlow tutorial example running on SageMaker Training in the cloud.

# %% [markdown]
# "Training Code"
#
# The first example script we'll look at demonstrates how to access information from the SageMaker environment, as well as parameters specified at runtime, from within your script. Here is the code:
#
# ```python
# import tensorflow as tf
# import os
# import json
# import argparse
#
#
# if __name__ =='__main__':
#     # Training environment metadata is available from environment variables.
#     # Lots of additional information available not used in this example, such as # gpus/cpus.
#     # Easy to interact with once loaded from json, since it's just a regular python dict.
#     train_env = json.loads(os.environ['SM_TRAINING_ENV'])
#     print(train_env)
#
#     # You can read script parameters either from SM_TRAINING_ENV, or by using argparse.
#     # Both approaches demonstrated here.
#     foo = float(train_env['hyperparameters']['foo'])
#
#     parser = argparse.ArgumentParser()
#     parser.add_argument('--bar', type=float)
#     args, unknown = parser.parse_known_args()
#     bar = args.bar
#
#     # Load training data file. SageMaker downloads it from S3 for you, and makes it
#     # accessible from the local file system.
#     train_data_dir = train_env['channel_input_dirs']['training']
#     data_file = os.path.join(train_data_dir, 'data.txt')
#     with open(data_file, 'r') as f:
#         print(f.readlines())
#
#     # TODO: output artifacts?
#
#     # Use script parameters to do a trivial TensorFlow operation using eager execution,
#     # similar to example from: https://www.tensorflow.org/guide/eager#setup_and_basic_usage
#     tf.enable_eager_execution()
#
#     m = tf.matmul([[foo]], [[bar]])
#     print("hello, {}".format(m))  # => "hello, [[12]]"
# ```
#
# You can modify this script by opening the file located in the same directory as this notebook through the Jupyter UI.

# %% [markdown]
# Control flow code
#
# The code below uses the TensorFlow class from SageMaker Python SDK to configure and manage the training environment. The actual training code to be executed, contained in 'script.py', will be executed in a container running the official SageMaker TensorFlow image. Note that because the 'train_instance_type' parameter is 'local', it will run the container locally, rather than on SageMaker's cloud infrastructure.
#
# This approach may seem cumbersome for initial development, and indeed it may be easier initially to iterate on your training code directly in the notebook. However, the advantage of the setup shown here is that it lets you verify the integration of your script with the SageMaker training environment, while still operating with relatively fast local iterations. And then, once you're ready, moving to the cloud is as simple as changing a few parameters.

# %%
from sagemaker.tensorflow import TensorFlow
import sagemaker

tfe = TensorFlow(entry_point='hello.py', role='SageMakerRole',
                #image_name='826912895975.dkr.ecr.us-west-2.amazonaws.com/preprod-tensorflow:scriptmode',
                image_name='tf-scriptmode',
                train_instance_type='local', train_instance_count=1,
                hyperparameters={'foo': '3', 'bar': '4'})

# TODO: remove S3 usage for local stuff
sess = sagemaker.Session()
s3_data = sess.upload_data('data.txt', key_prefix='')
tfe.fit({'training': s3_data})
# Out:
# WARNING:sagemaker.local.local_session:Windows Support for Local Mode is Experimental
# INFO:sagemaker:Creating training-job with name: tf-scriptmode-2018-10-02-18-05-31-608
# Creating tmp04zy0_qu_algo-1-3KW1K_1 ...
# Attaching to tmp04zy0_qu_algo-1-3KW1K_12mdone
# algo-1-3KW1K_1  | 2018-10-02 18:05:36,683 sagemaker-containers INFO     Imported framework tf_container.training
# algo-1-3KW1K_1  | 2018-10-02 18:05:36,693 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-3KW1K_1  | 2018-10-02 18:05:37,262 sagemaker-containers INFO     Module hello does not provide a setup.py.
# algo-1-3KW1K_1  | Generating setup.py
# algo-1-3KW1K_1  | 2018-10-02 18:05:37,262 sagemaker-containers INFO     Generating setup.cfg
# algo-1-3KW1K_1  | 2018-10-02 18:05:37,263 sagemaker-containers INFO     Generating MANIFEST.in
# algo-1-3KW1K_1  | 2018-10-02 18:05:37,263 sagemaker-containers INFO     Installing module with the following command:
# algo-1-3KW1K_1  | /usr/bin/python -m pip install -vvv -U .
# algo-1-3KW1K_1  | Created temporary directory: /tmp/pip-ephem-wheel-cache-sZ8Smy
# algo-1-3KW1K_1  | Created temporary directory: /tmp/pip-req-tracker-_d5x5w
# algo-1-3KW1K_1  | Created requirements tracker '/tmp/pip-req-tracker-_d5x5w'
# algo-1-3KW1K_1  | Created temporary directory: /tmp/pip-install-HiLj0m
# algo-1-3KW1K_1  | Processing /tmp/tmpYYmjTM/module_dir
# algo-1-3KW1K_1  |   Created temporary directory: /tmp/pip-req-build-0CPshE
# algo-1-3KW1K_1  |   Added file:///tmp/tmpYYmjTM/module_dir to build tracker '/tmp/pip-req-tracker-_d5x5w'
# algo-1-3KW1K_1  |   Running setup.py (path:/tmp/pip-req-build-0CPshE/setup.py) egg_info for package from file:///tmp/tmpYYmjTM/module_dir
# algo-1-3KW1K_1  |     Running command python setup.py egg_info
# algo-1-3KW1K_1  |     WARNING: '' not a valid package name; please use only .-separated package names in setup.py
# algo-1-3KW1K_1  |     running egg_info
# algo-1-3KW1K_1  |     creating pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |     writing pip-egg-info/hello.egg-info/PKG-INFO
# algo-1-3KW1K_1  |     writing top-level names to pip-egg-info/hello.egg-info/top_level.txt
# algo-1-3KW1K_1  |     writing dependency_links to pip-egg-info/hello.egg-info/dependency_links.txt
# algo-1-3KW1K_1  |     writing manifest file 'pip-egg-info/hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |     reading manifest file 'pip-egg-info/hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |     reading manifest template 'MANIFEST.in'
# algo-1-3KW1K_1  |     warning: no previously-included files matching '__pycache__*' found under directory '.'
# algo-1-3KW1K_1  |     warning: no previously-included files matching '*.pyc' found under directory '.'
# algo-1-3KW1K_1  |     warning: no previously-included files matching '*.pyo' found under directory '.'
# algo-1-3KW1K_1  |     writing manifest file 'pip-egg-info/hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |   Source in /tmp/pip-req-build-0CPshE has version 1.0.0, which satisfies requirement hello==1.0.0 from file:///tmp/tmpYYmjTM/module_dir
# algo-1-3KW1K_1  |   Removed hello==1.0.0 from file:///tmp/tmpYYmjTM/module_dir from build tracker '/tmp/pip-req-tracker-_d5x5w'
# algo-1-3KW1K_1  | Could not parse version from link: file:///tmp/tmpYYmjTM/module_dir
# algo-1-3KW1K_1  | Building wheels for collected packages: hello
# algo-1-3KW1K_1  |   Created temporary directory: /tmp/pip-wheel-oX82uB
# algo-1-3KW1K_1  |   Running setup.py bdist_wheel for hello ...   Destination directory: /tmp/pip-wheel-oX82uB
# algo-1-3KW1K_1  |   Running command /usr/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-req-build-0CPshE/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-oX82uB --python-tag cp27
# algo-1-3KW1K_1  |   WARNING: '' not a valid package name; please use only .-separated package names in setup.py
# algo-1-3KW1K_1  |   running bdist_wheel
# algo-1-3KW1K_1  |   running build
# algo-1-3KW1K_1  |   running build_py
# algo-1-3KW1K_1  |   creating build
# algo-1-3KW1K_1  |   creating build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying hello.py -> build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying setup.py -> build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   running egg_info
# algo-1-3KW1K_1  |   creating hello.egg-info
# algo-1-3KW1K_1  |   writing hello.egg-info/PKG-INFO
# algo-1-3KW1K_1  |   writing top-level names to hello.egg-info/top_level.txt
# algo-1-3KW1K_1  |   writing dependency_links to hello.egg-info/dependency_links.txt
# algo-1-3KW1K_1  |   writing manifest file 'hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |   reading manifest file 'hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |   reading manifest template 'MANIFEST.in'
# algo-1-3KW1K_1  |   warning: no previously-included files matching '__pycache__*' found under directory '.'
# algo-1-3KW1K_1  |   warning: no previously-included files matching '*.pyc' found under directory '.'
# algo-1-3KW1K_1  |   warning: no previously-included files matching '*.pyo' found under directory '.'
# algo-1-3KW1K_1  |   writing manifest file 'hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |   copying MANIFEST.in -> build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying setup.cfg -> build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying pip-delete-this-directory.txt -> build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   creating build/lib.linux-x86_64-2.7/build
# algo-1-3KW1K_1  |   creating build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/hello.py -> build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/setup.py -> build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   creating build/lib.linux-x86_64-2.7/hello.egg-info
# algo-1-3KW1K_1  |   copying hello.egg-info/PKG-INFO -> build/lib.linux-x86_64-2.7/hello.egg-info
# algo-1-3KW1K_1  |   copying hello.egg-info/SOURCES.txt -> build/lib.linux-x86_64-2.7/hello.egg-info
# algo-1-3KW1K_1  |   copying hello.egg-info/dependency_links.txt -> build/lib.linux-x86_64-2.7/hello.egg-info
# algo-1-3KW1K_1  |   copying hello.egg-info/top_level.txt -> build/lib.linux-x86_64-2.7/hello.egg-info
# algo-1-3KW1K_1  |   creating build/lib.linux-x86_64-2.7/pip-egg-info
# algo-1-3KW1K_1  |   creating build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying pip-egg-info/hello.egg-info/PKG-INFO -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying pip-egg-info/hello.egg-info/SOURCES.txt -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying pip-egg-info/hello.egg-info/dependency_links.txt -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying pip-egg-info/hello.egg-info/top_level.txt -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   installing to build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   running install
# algo-1-3KW1K_1  |   running install_lib
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel/pip-egg-info
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel/build
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel/build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7/hello.py -> build/bdist.linux-x86_64/wheel/build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7/setup.py -> build/bdist.linux-x86_64/wheel/build/lib.linux-x86_64-2.7
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/hello.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/hello.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/hello.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/hello.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/hello.egg-info
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/hello.py -> build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/pip-delete-this-directory.txt -> build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/MANIFEST.in -> build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/setup.py -> build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   copying build/lib.linux-x86_64-2.7/setup.cfg -> build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  |   running install_egg_info
# algo-1-3KW1K_1  |   Copying hello.egg-info to build/bdist.linux-x86_64/wheel/hello-1.0.0-py2.7.egg-info
# algo-1-3KW1K_1  |   running install_scripts
# algo-1-3KW1K_1  |   creating build/bdist.linux-x86_64/wheel/hello-1.0.0.dist-info/WHEEL
# algo-1-3KW1K_1  |   creating '/tmp/pip-wheel-oX82uB/hello-1.0.0-py2.py3-none-any.whl' and adding '.' to it
# algo-1-3KW1K_1  |   adding 'MANIFEST.in'
# algo-1-3KW1K_1  |   adding 'hello.py'
# algo-1-3KW1K_1  |   adding 'pip-delete-this-directory.txt'
# algo-1-3KW1K_1  |   adding 'setup.cfg'
# algo-1-3KW1K_1  |   adding 'setup.py'
# algo-1-3KW1K_1  |   adding 'build/lib.linux-x86_64-2.7/hello.py'
# algo-1-3KW1K_1  |   adding 'build/lib.linux-x86_64-2.7/setup.py'
# algo-1-3KW1K_1  |   adding 'hello.egg-info/PKG-INFO'
# algo-1-3KW1K_1  |   adding 'hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |   adding 'hello.egg-info/dependency_links.txt'
# algo-1-3KW1K_1  |   adding 'hello.egg-info/top_level.txt'
# algo-1-3KW1K_1  |   adding 'pip-egg-info/hello.egg-info/PKG-INFO'
# algo-1-3KW1K_1  |   adding 'pip-egg-info/hello.egg-info/SOURCES.txt'
# algo-1-3KW1K_1  |   adding 'pip-egg-info/hello.egg-info/dependency_links.txt'
# algo-1-3KW1K_1  |   adding 'pip-egg-info/hello.egg-info/top_level.txt'
# algo-1-3KW1K_1  |   adding 'hello-1.0.0.dist-info/top_level.txt'
# algo-1-3KW1K_1  |   adding 'hello-1.0.0.dist-info/WHEEL'
# algo-1-3KW1K_1  |   adding 'hello-1.0.0.dist-info/METADATA'
# algo-1-3KW1K_1  |   adding 'hello-1.0.0.dist-info/RECORD'
# algo-1-3KW1K_1  |   removing build/bdist.linux-x86_64/wheel
# algo-1-3KW1K_1  | done
# algo-1-3KW1K_1  |   Stored in directory: /tmp/pip-ephem-wheel-cache-sZ8Smy/wheels/22/4c/0a/018113778ce750d2ac868564ff8f487e3b3eefcdf60a0b6a11
# algo-1-3KW1K_1  |   Removing source in /tmp/pip-req-build-0CPshE
# algo-1-3KW1K_1  | Successfully built hello
# algo-1-3KW1K_1  | Installing collected packages: hello
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  |   Removing source in /tmp/pip-install-HiLj0m/hello
# algo-1-3KW1K_1  | Successfully installed hello-1.0.0
# algo-1-3KW1K_1  | Cleaning up...
# algo-1-3KW1K_1  | Removed build tracker '/tmp/pip-req-tracker-_d5x5w'
# algo-1-3KW1K_1  | 2018-10-02 18:05:38,956 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-3KW1K_1  | 2018-10-02 18:05:38,975 sagemaker-containers INFO     Invoking user script
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | Training Env:
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | {
# algo-1-3KW1K_1  |     "network_interface_name": "ethwe",
# algo-1-3KW1K_1  |     "log_level": 20,
# algo-1-3KW1K_1  |     "model_dir": "/opt/ml/model",
# algo-1-3KW1K_1  |     "num_gpus": 0,
# algo-1-3KW1K_1  |     "channel_input_dirs": {
# algo-1-3KW1K_1  |         "training": "/opt/ml/input/data/training"
# algo-1-3KW1K_1  |     },
# algo-1-3KW1K_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-3KW1K_1  |     "num_cpus": 2,
# algo-1-3KW1K_1  |     "input_data_config": {
# algo-1-3KW1K_1  |         "training": {
# algo-1-3KW1K_1  |             "ContentType": "application/octet-stream"
# algo-1-3KW1K_1  |         }
# algo-1-3KW1K_1  |     },
# algo-1-3KW1K_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-3KW1K_1  |     "hosts": [
# algo-1-3KW1K_1  |         "algo-1-3KW1K"
# algo-1-3KW1K_1  |     ],
# algo-1-3KW1K_1  |     "output_dir": "/opt/ml/output",
# algo-1-3KW1K_1  |     "module_dir": "s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608/source/sourcedir.tar.gz",
# algo-1-3KW1K_1  |     "hyperparameters": {
# algo-1-3KW1K_1  |         "training_steps": null,
# algo-1-3KW1K_1  |         "checkpoint_path": "s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\\checkpoints",
# algo-1-3KW1K_1  |         "bar": "4",
# algo-1-3KW1K_1  |         "foo": "3",
# algo-1-3KW1K_1  |         "evaluation_steps": null
# algo-1-3KW1K_1  |     },
# algo-1-3KW1K_1  |     "module_name": "hello",
# algo-1-3KW1K_1  |     "current_host": "algo-1-3KW1K",
# algo-1-3KW1K_1  |     "input_dir": "/opt/ml/input",
# algo-1-3KW1K_1  |     "job_name": null,
# algo-1-3KW1K_1  |     "resource_config": {
# algo-1-3KW1K_1  |         "hosts": [
# algo-1-3KW1K_1  |             "algo-1-3KW1K"
# algo-1-3KW1K_1  |         ],
# algo-1-3KW1K_1  |         "current_host": "algo-1-3KW1K"
# algo-1-3KW1K_1  |     },
# algo-1-3KW1K_1  |     "framework_module": "tf_container.training:main"
# algo-1-3KW1K_1  | }
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | Environment variables:
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | SM_HOSTS=["algo-1-3KW1K"]
# algo-1-3KW1K_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-3KW1K_1  | SM_MODULE_NAME=hello
# algo-1-3KW1K_1  | SM_TRAINING_ENV={"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1-3KW1K","framework_module":"tf_container.training:main","hosts":["algo-1-3KW1K"],"hyperparameters":{"bar":"4","checkpoint_path":"s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\\checkpoints","evaluation_steps":null,"foo":"3","training_steps":null},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"ContentType":"application/octet-stream"}},"input_dir":"/opt/ml/input","job_name":null,"log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608/source/sourcedir.tar.gz","module_name":"hello","network_interface_name":"ethwe","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1-3KW1K","hosts":["algo-1-3KW1K"]}}
# algo-1-3KW1K_1  | SM_CHANNELS=["training"]
# algo-1-3KW1K_1  | SM_INPUT_DATA_CONFIG={"training":{"ContentType":"application/octet-stream"}}
# algo-1-3KW1K_1  | SM_NETWORK_INTERFACE_NAME=ethwe
# algo-1-3KW1K_1  | SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\checkpoints
# algo-1-3KW1K_1  | SM_HP_TRAINING_STEPS=
# algo-1-3KW1K_1  | SM_HP_EVALUATION_STEPS=
# algo-1-3KW1K_1  | SM_USER_ARGS=["--bar","4","--checkpoint_path","s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\\checkpoints","--evaluation_steps","","--foo","3","--training_steps",""]
# algo-1-3KW1K_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-3KW1K_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-3KW1K_1  | SM_NUM_GPUS=0
# algo-1-3KW1K_1  | SM_MODULE_DIR=s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608/source/sourcedir.tar.gz
# algo-1-3KW1K_1  | SM_HP_BAR=4
# algo-1-3KW1K_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-3KW1K_1  | SM_NUM_CPUS=2
# algo-1-3KW1K_1  | SM_FRAMEWORK_MODULE=tf_container.training:main
# algo-1-3KW1K_1  | SM_HPS={"bar":"4","checkpoint_path":"s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\\checkpoints","evaluation_steps":null,"foo":"3","training_steps":null}
# algo-1-3KW1K_1  | SM_CURRENT_HOST=algo-1-3KW1K
# algo-1-3KW1K_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-3KW1K_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-3KW1K","hosts":["algo-1-3KW1K"]}
# algo-1-3KW1K_1  | SM_LOG_LEVEL=20
# algo-1-3KW1K_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-3KW1K_1  | SM_HP_FOO=3
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | Invoking script with the following command:
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | /usr/bin/python -m hello --bar 4 --checkpoint_path s3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\checkpoints --evaluation_steps  --foo 3 --training_steps
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  |
# algo-1-3KW1K_1  | {u'num_gpus': 0, u'network_interface_name': u'ethwe', u'log_level': 20, u'module_dir': u's3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608/source/sourcedir.tar.gz', u'job_name': None, u'module_name': u'hello', u'input_config_dir': u'/opt/ml/input/config', u'num_cpus': 2, u'input_data_config': {u'training': {u'ContentType': u'application/octet-stream'}}, u'output_data_dir': u'/opt/ml/output/data', u'hosts': [u'algo-1-3KW1K'], u'output_dir': u'/opt/ml/output', u'model_dir': u'/opt/ml/model', u'hyperparameters': {u'training_steps': None, u'checkpoint_path': u's3://sagemaker-us-west-2-826912895975/tf-scriptmode-2018-10-02-18-05-31-608\\checkpoints', u'bar': u'4', u'foo': u'3', u'evaluation_steps': None}, u'current_host': u'algo-1-3KW1K', u'input_dir': u'/opt/ml/input', u'channel_input_dirs': {u'training': u'/opt/ml/input/data/training'}, u'resource_config': {u'hosts': [u'algo-1-3KW1K'], u'current_host': u'algo-1-3KW1K'}, u'framework_module': u'tf_container.training:main'}
# algo-1-3KW1K_1  | ['1\n', '2\n', '3\n']
# algo-1-3KW1K_1  | hello, [[12.]]
# algo-1-3KW1K_1  | 2018-10-02 18:05:40,271 sagemaker-containers INFO     Reporting training SUCCESS
# tmp04zy0_qu_algo-1-3KW1K_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %% [markdown]
# You can see the sagemaker environment information printed out, as well as the result of our TensorFlow computation.

# %% [markdown]
# Running on the SageMaker Cloud
#
# Once you have a script working to your satisfaction in local mode, simply change the train_instance_type parameter to run it on SageMaker's infrastructure. The SageMaker Python SDK will create a training job for you behind the scenes for you. Once the instances are launched and your script has started running, its output will be streamed in real time below.

# %%
tfe = TensorFlow(entry_point='hello.py', role='SageMakerRole',
                image_name='826912895975.dkr.ecr.us-west-2.amazonaws.com/preprod-tensorflow:scriptmode',
                train_instance_type='ml.c4.xlarge', # only parameter changed
                train_instance_count=1,
                hyperparameters={'foo': '3', 'bar': '4'})

tfe.fit({'training': s3_data})
# Out:
# INFO:sagemaker:Creating training-job with name: preprod-tensorflow-2018-10-02-18-07-58-250
# 2018-10-02 18:08:01 Starting - Starting the training job...
# Launching requested ML instances......
# Preparing the instances for training...
# 2018-10-02 18:09:42 Downloading - Downloading input data
# 2018-10-02 18:09:48 Training - Downloading the training image...
# 2018-10-02 18:10:35 Uploading - Uploading generated training model
# 2018-10-02 18:10:40 Completed - Training job completed
#
# 2018-10-02 18:10:28,985 sagemaker-containers INFO     Imported framework tf_container.training
# 2018-10-02 18:10:28,988 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-10-02 18:10:29,374 sagemaker-containers INFO     Module hello does not provide a setup.py.
# Generating setup.py
# 2018-10-02 18:10:29,375 sagemaker-containers INFO     Generating setup.cfg
# 2018-10-02 18:10:29,375 sagemaker-containers INFO     Generating MANIFEST.in
# 2018-10-02 18:10:29,375 sagemaker-containers INFO     Installing module with the following command:
# /usr/bin/python -m pip install -vvv -U .
# Created temporary directory: /tmp/pip-ephem-wheel-cache-CRrFc8
# Created temporary directory: /tmp/pip-req-tracker-D_ytbf
# Created requirements tracker '/tmp/pip-req-tracker-D_ytbf'
# Created temporary directory: /tmp/pip-install-vO9HZr
# Processing /tmp/tmp7kHIWO/module_dir
#   Created temporary directory: /tmp/pip-req-build-Qyb5kc
#   Added file:///tmp/tmp7kHIWO/module_dir to build tracker '/tmp/pip-req-tracker-D_ytbf'
#   Running setup.py (path:/tmp/pip-req-build-Qyb5kc/setup.py) egg_info for package from file:///tmp/tmp7kHIWO/module_dir
#     Running command python setup.py egg_info
#     WARNING: '' not a valid package name; please use only .-separated package names in setup.py
#     running egg_info
#     creating pip-egg-info/hello.egg-info
#     writing pip-egg-info/hello.egg-info/PKG-INFO
#     writing top-level names to pip-egg-info/hello.egg-info/top_level.txt
#     writing dependency_links to pip-egg-info/hello.egg-info/dependency_links.txt
#     writing manifest file 'pip-egg-info/hello.egg-info/SOURCES.txt'
#     reading manifest file 'pip-egg-info/hello.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no previously-included files matching '__pycache__*' found under directory '.'
#     warning: no previously-included files matching '*.pyc' found under directory '.'
#     warning: no previously-included files matching '*.pyo' found under directory '.'
#     writing manifest file 'pip-egg-info/hello.egg-info/SOURCES.txt'
#   Source in /tmp/pip-req-build-Qyb5kc has version 1.0.0, which satisfies requirement hello==1.0.0 from file:///tmp/tmp7kHIWO/module_dir
#   Removed hello==1.0.0 from file:///tmp/tmp7kHIWO/module_dir from build tracker '/tmp/pip-req-tracker-D_ytbf'
# Could not parse version from link: file:///tmp/tmp7kHIWO/module_dir
# Building wheels for collected packages: hello
#   Created temporary directory: /tmp/pip-wheel-b7Z02x
#   Running setup.py bdist_wheel for hello: started
#   Destination directory: /tmp/pip-wheel-b7Z02x
#   Running command /usr/bin/python -u -c "import setuptools, tokenize;__file__='/tmp/pip-req-build-Qyb5kc/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /tmp/pip-wheel-b7Z02x --python-tag cp27
#   WARNING: '' not a valid package name; please use only .-separated package names in setup.py
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-2.7
#   copying setup.py -> build/lib.linux-x86_64-2.7
#   copying hello.py -> build/lib.linux-x86_64-2.7
#   running egg_info
#   creating hello.egg-info
#   writing hello.egg-info/PKG-INFO
#   writing top-level names to hello.egg-info/top_level.txt
#   writing dependency_links to hello.egg-info/dependency_links.txt
#   writing manifest file 'hello.egg-info/SOURCES.txt'
#   reading manifest file 'hello.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no previously-included files matching '__pycache__*' found under directory '.'
#   warning: no previously-included files matching '*.pyc' found under directory '.'
#   warning: no previously-included files matching '*.pyo' found under directory '.'
#   writing manifest file 'hello.egg-info/SOURCES.txt'
#   copying MANIFEST.in -> build/lib.linux-x86_64-2.7
#   copying setup.cfg -> build/lib.linux-x86_64-2.7
#   copying pip-delete-this-directory.txt -> build/lib.linux-x86_64-2.7
#   creating build/lib.linux-x86_64-2.7/build
#   creating build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7
#   copying build/lib.linux-x86_64-2.7/hello.py -> build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7
#   copying build/lib.linux-x86_64-2.7/setup.py -> build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7
#   creating build/lib.linux-x86_64-2.7/hello.egg-info
#   copying hello.egg-info/PKG-INFO -> build/lib.linux-x86_64-2.7/hello.egg-info
#   copying hello.egg-info/SOURCES.txt -> build/lib.linux-x86_64-2.7/hello.egg-info
#   copying hello.egg-info/dependency_links.txt -> build/lib.linux-x86_64-2.7/hello.egg-info
#   copying hello.egg-info/top_level.txt -> build/lib.linux-x86_64-2.7/hello.egg-info
#   creating build/lib.linux-x86_64-2.7/pip-egg-info
#   creating build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
#   copying pip-egg-info/hello.egg-info/PKG-INFO -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
#   copying pip-egg-info/hello.egg-info/SOURCES.txt -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
#   copying pip-egg-info/hello.egg-info/dependency_links.txt -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
#   copying pip-egg-info/hello.egg-info/top_level.txt -> build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info
#   installing to build/bdist.linux-x86_64/wheel
#   running install
#   running install_lib
#   creating build/bdist.linux-x86_64
#   creating build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-2.7/setup.cfg -> build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-2.7/MANIFEST.in -> build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/hello.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/hello.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/hello.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/hello.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/hello.egg-info
#   creating build/bdist.linux-x86_64/wheel/pip-egg-info
#   creating build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/PKG-INFO -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/pip-egg-info/hello.egg-info/top_level.txt -> build/bdist.linux-x86_64/wheel/pip-egg-info/hello.egg-info
#   copying build/lib.linux-x86_64-2.7/pip-delete-this-directory.txt -> build/bdist.linux-x86_64/wheel
#   copying build/lib.linux-x86_64-2.7/setup.py -> build/bdist.linux-x86_64/wheel
#   creating build/bdist.linux-x86_64/wheel/build
#   creating build/bdist.linux-x86_64/wheel/build/lib.linux-x86_64-2.7
#   copying build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7/setup.py -> build/bdist.linux-x86_64/wheel/build/lib.linux-x86_64-2.7
#   copying build/lib.linux-x86_64-2.7/build/lib.linux-x86_64-2.7/hello.py -> build/bdist.linux-x86_64/wheel/build/lib.linux-x86_64-2.7
#   copying build/lib.linux-x86_64-2.7/hello.py -> build/bdist.linux-x86_64/wheel
#   running install_egg_info
#   Copying hello.egg-info to build/bdist.linux-x86_64/wheel/hello-1.0.0-py2.7.egg-info
#   running install_scripts
#   creating build/bdist.linux-x86_64/wheel/hello-1.0.0.dist-info/WHEEL
#   creating '/tmp/pip-wheel-b7Z02x/hello-1.0.0-py2.py3-none-any.whl' and adding '.' to it
#   adding 'MANIFEST.in'
#   adding 'hello.py'
#   adding 'pip-delete-this-directory.txt'
#   adding 'setup.cfg'
#   adding 'setup.py'
#   adding 'build/lib.linux-x86_64-2.7/hello.py'
#   adding 'build/lib.linux-x86_64-2.7/setup.py'
#   adding 'hello.egg-info/PKG-INFO'
#   adding 'hello.egg-info/SOURCES.txt'
#   adding 'hello.egg-info/dependency_links.txt'
#   adding 'hello.egg-info/top_level.txt'
#   adding 'pip-egg-info/hello.egg-info/PKG-INFO'
#   adding 'pip-egg-info/hello.egg-info/SOURCES.txt'
#   adding 'pip-egg-info/hello.egg-info/dependency_links.txt'
#   adding 'pip-egg-info/hello.egg-info/top_level.txt'
#   adding 'hello-1.0.0.dist-info/top_level.txt'
#   adding 'hello-1.0.0.dist-info/WHEEL'
#   adding 'hello-1.0.0.dist-info/METADATA'
#   adding 'hello-1.0.0.dist-info/RECORD'
#   removing build/bdist.linux-x86_64/wheel
#   Running setup.py bdist_wheel for hello: finished with status 'done'
#   Stored in directory: /tmp/pip-ephem-wheel-cache-CRrFc8/wheels/b8/9f/33/0c4a93739608d2e98fc21f5260fdc24ac4dc6111274228963f
#   Removing source in /tmp/pip-req-build-Qyb5kc
# Successfully built hello
# Installing collected packages: hello
#
#   Removing source in /tmp/pip-install-vO9HZr/hello
# Successfully installed hello-1.0.0
# Cleaning up...
# Removed build tracker '/tmp/pip-req-tracker-D_ytbf'
# 2018-10-02 18:10:30,525 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2018-10-02 18:10:30,536 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "network_interface_name": "ethwe",
#     "log_level": 20,
#     "model_dir": "/opt/ml/model",
#     "num_gpus": 0,
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "num_cpus": 4,
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "RecordWrapperType": "None",
#             "S3DistributionType": "FullyReplicated"
#         }
#     },
#     "output_data_dir": "/opt/ml/output/data",
#     "hosts": [
#         "algo-1"
#     ],
#     "output_dir": "/opt/ml/output",
#     "module_dir": "s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250/source/sourcedir.tar.gz",
#     "hyperparameters": {
#         "training_steps": null,
#         "checkpoint_path": "s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\\checkpoints",
#         "bar": "4",
#         "foo": "3",
#         "evaluation_steps": null
#     },
#     "module_name": "hello",
#     "current_host": "algo-1",
#     "input_dir": "/opt/ml/input",
#     "job_name": "preprod-tensorflow-2018-10-02-18-07-58-250",
#     "resource_config": {
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "ethwe",
#         "current_host": "algo-1"
#     },
#     "framework_module": "tf_container.training:main"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_INPUT_DIR=/opt/ml/input
# SM_MODULE_NAME=hello
# SM_TRAINING_ENV={"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"tf_container.training:main","hosts":["algo-1"],"hyperparameters":{"bar":"4","checkpoint_path":"s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\\checkpoints","evaluation_steps":null,"foo":"3","training_steps":null},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","job_name":"preprod-tensorflow-2018-10-02-18-07-58-250","log_level":20,"model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250/source/sourcedir.tar.gz","module_name":"hello","network_interface_name":"ethwe","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}}
# SM_CHANNELS=["training"]
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NETWORK_INTERFACE_NAME=ethwe
# SM_HP_CHECKPOINT_PATH=s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\checkpoints
# SM_HP_TRAINING_STEPS=
# SM_HP_EVALUATION_STEPS=
# SM_USER_ARGS=["--bar","4","--checkpoint_path","s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\\checkpoints","--evaluation_steps","","--foo","3","--training_steps",""]
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_MODEL_DIR=/opt/ml/model
# SM_NUM_GPUS=0
# SM_MODULE_DIR=s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250/source/sourcedir.tar.gz
# SM_HP_BAR=4
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_FRAMEWORK_MODULE=tf_container.training:main
# SM_HPS={"bar":"4","checkpoint_path":"s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\\checkpoints","evaluation_steps":null,"foo":"3","training_steps":null}
# SM_CURRENT_HOST=algo-1
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"ethwe"}
# SM_LOG_LEVEL=20
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_HP_FOO=3
#
# Invoking script with the following command:
#
# /usr/bin/python -m hello --bar 4 --checkpoint_path s3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\checkpoints --evaluation_steps  --foo 3 --training_steps
#
#
# {u'num_gpus': 0, u'network_interface_name': u'ethwe', u'log_level': 20, u'module_dir': u's3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250/source/sourcedir.tar.gz', u'job_name': u'preprod-tensorflow-2018-10-02-18-07-58-250', u'module_name': u'hello', u'input_config_dir': u'/opt/ml/input/config', u'num_cpus': 4, u'input_data_config': {u'training': {u'TrainingInputMode': u'File', u'RecordWrapperType': u'None', u'S3DistributionType': u'FullyReplicated'}}, u'output_data_dir': u'/opt/ml/output/data', u'hosts': [u'algo-1'], u'output_dir': u'/opt/ml/output', u'model_dir': u'/opt/ml/model', u'hyperparameters': {u'training_steps': None, u'checkpoint_path': u's3://sagemaker-us-west-2-826912895975/preprod-tensorflow-2018-10-02-18-07-58-250\\checkpoints', u'bar': u'4', u'foo': u'3', u'evaluation_steps': None}, u'current_host': u'algo-1', u'input_dir': u'/opt/ml/input', u'channel_input_dirs': {u'training': u'/opt/ml/input/data/training'}, u'resource_config': {u'hosts': [u'algo-1'], u'network_interface_name': u'ethwe', u'current_host': u'algo-1'}, u'framework_module': u'tf_container.training:main'}
# ['1\n', '2\n', '3\n']
# hello, [[12.]]
# 2018-10-02 18:10:32,604 sagemaker-containers INFO     Reporting training SUCCESS
# Billable seconds: 59
